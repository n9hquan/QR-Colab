# %% [markdown]
# <a href="https://colab.research.google.com/github/n9quan/QR_Colab/blob/main/WS_2.0_Intro_to_surveys_Nguyen_Chinh_Quan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook we will take a careful look at
#
# *   The Survey of Consumer Finances and
# *   Vietnam Household Living Standard Survey
#
# to understand their structure and extract data needed for our project.

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import io

# %% [markdown]
# # The Survey of Consumer Finances
# "The Survey of Consumer Finances (SCF) is normally a triennial cross-sectional survey of U.S. families. The survey data include information on families’ balance sheets, pensions, income, and demographic characteristics. Information is also included from related surveys of pension providers and the earlier such surveys conducted by the Federal Reserve Board. No other study for the country collects comparable information. Data from the SCF are widely used, from analysis at the Federal Reserve and other branches of government to scholarly work at the major economic research centers." (The Federal Reserve Board)

# %% [markdown]
# **Exercise**: Please visit the homepage of the Federal Reserve Board (https://www.federalreserve.gov/econres/scfindex.htm) and download the surveys from 1989 to 2019. Please import the data files and visualize them.

# %%
# Importing Excel file
uploaded = files.upload()
wealth89 = pd.read_excel(io.BytesIO(uploaded["filename.xlsx"]), sheet_name='sheet_name', skiprows=1)
# Out:
#      <input type="file" id="files-ec67d5b1-993a-453e-80a1-82e782c521fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec67d5b1-993a-453e-80a1-82e782c521fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Exercise**: Extract income and wealth data, or any data you are interested in. Create box plots and histograms.

# %%
# Insert solution here

# %% [markdown]
# # Vietnam Household Living Standard Survey
# "To evaluate living standards for policy-making and socio-economic development planning, from 1993 to now the General Statistics Office (GSO) conducts the Viet Nam Household Living Standards Survey (VHLSS). From 2002 to 2010, this survey has been conducted regularly by the GSO every two years. From 2011 to 2020, VHLSS are conducted annually. However, the odd-numbered year surveys only collect data on demographics, employment and income. The purpose of the VHLSS in order to systematically monitor and supervise the living standards of different population groups in Viet Nam; to monitor and evaluate the implementation of the Comprehensive Poverty Reduction and Growth Strategy; and to contribute to the evaluation of achievement of the Sustainable Development Goals (SDGs) and Vietnam’s socio-economic development goals." (The General Statistics Office)

# %% [markdown]
# **Exercise**: Go to [this website](https://www.niengiamthongke.net/kh%E1%BA%A3o-s%C3%A1t/vhlss-2020) and download the surveys for 2008, 2010, 2012, and 2014. Please import the data files and visualize them.

# %%
# To import Stata data file we use the following code
uploaded = files.upload()
vhlss08 = pd.read_stata(io.BytesIO(uploaded["ho12.dta"]))
# Out:
#      <input type="file" id="files-6dd6b967-9682-46b7-ab61-182fe7f9cf5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6dd6b967-9682-46b7-ab61-182fe7f9cf5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
vhlss08
# Out:
#       tinh  huyen       xa  diaban  hoso m4b0c1  m4b0tn  m4b1a  m4b1b  m4b11t  \
# 0        1      1      4.0      12    13  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 1        1      1      4.0      12    14  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 2        1      1      4.0      12    15  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 3        1      1      7.0      22    13  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 4        1      1      7.0      22    15  Kh«ng     0.0  Kh«ng  Kh«ng       0
# ...    ...    ...      ...     ...   ...    ...     ...    ...    ...     ...
# 9397    96    973  32242.0      21    15  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 9398    96    973  32242.0      21    19  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 9399    96    973  32248.0      12    13     Cã  3000.0  Kh«ng  Kh«ng       0
# 9400    96    973  32248.0      12    14  Kh«ng     0.0  Kh«ng  Kh«ng       0
# 9401    96    973  32248.0      12    15     Cã     0.0  Kh«ng  Kh«ng       0
#
# ...

# %% [markdown]
# **Exercise**: Try finding the data that would be useful for your poster. Create box plots and histograms.

# %%
# Insert solution here

# %% [markdown]
# # What if your desired data is not publicly available?
#
# In this case, you may design a questionnaire and conduct a survey. [Google Forms](https://docs.google.com/forms/u/0/) is a good starting point. Before you work with Google Forms, let us do an exercise with Excel.

# %%
# Importing Excel file
uploaded = files.upload()
wealth89 = pd.read_excel(io.BytesIO(uploaded["ineq_sur.xlsx"]), sheet_name='wealth', skiprows=1)
